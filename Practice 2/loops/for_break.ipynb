# %%
for letter in "Python":
    if letter == "h":
        break

    print(letter)

# %%
umbers = [3, 7, 1, 9, 5]

for num in numbers:
    if num == 9:
        print("Найдено!")
        break

    print(num)

# %%
for i in range(10):
    if i == 5:
        break

    print(i)

# %% [markdown]
# Что делает break?
# break полностью останавливает цикл
