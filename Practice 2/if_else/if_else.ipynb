# %%
number = 7

if number % 2 == 0:
    print("Чётное")
else:
    print("Нечётное")

# %%
password = "123"

if password == "1234":
    print("Вход выполнен")
else:
    print("Неверный пароль")

# %%
age = 16

if age >= 18:
    print("Доступ разрешён")
else:
    print("Доступ запрещён")

# %% [markdown]
# if условие:
#     код_1
# else:
#     код_2
