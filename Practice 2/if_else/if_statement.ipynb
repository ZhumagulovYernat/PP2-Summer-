# %%
is_student = True

if is_student:
    print("Добро пожаловать!")

# %%
temperature = 30

if temperature > 25:
    print("Сегодня жарко")

# %%
age = 20

if age >= 18:
    print("Ты совершеннолетний")
