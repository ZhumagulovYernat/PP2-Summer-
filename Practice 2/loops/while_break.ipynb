# %%
while True:

    password = input("Введите пароль: ")

    if password == "1234":
        print("Доступ разрешён")
        break

    print("Неверный пароль")

# %%
number = 1

while True:

    if number == 7:
        print("Найдено!")
        break

    print(number)
    number += 1

# %%
i = 1

while i <= 10:

    if i == 5:
        break

    print(i)
    i += 1
