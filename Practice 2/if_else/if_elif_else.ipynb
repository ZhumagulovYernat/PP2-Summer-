# %%
number = 15

if number > 20:
    print("Больше 20")

elif number > 10:
    print("Больше 10")

elif number > 5:
    print("Больше 5")

# %%
temperature = 15

if temperature > 25:
    print("Жарко")
elif temperature > 10:
    print("Тепло")
else:
    print("Холодно")

# %%
score = 85

if score >= 90:
    print("Отлично")
elif score >= 70:
    print("Хорошо")
else:
    print("Нужно подтянуться")

# %% [markdown]
# if условие1:
#     код
# elif условие2:
#     код
# else:
#     код
