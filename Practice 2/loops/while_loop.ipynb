# %%
number = 1
total = 0

while number <= 5:
    total += number
    number += 1

print(total)

# %%
i = 1

while i <= 5:
    print(i)
    i += 1

# %%
count = 5

while count > 0:
    print(count)
    count -= 1

print("Старт!")

# %% [markdown]
# while условие:
#     код
