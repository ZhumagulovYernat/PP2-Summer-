# %%
for i in range(1, 11):
    print(f"5 x {i} = {5 * i}")

# %%
fruits = ["apple", "banana", "orange"]

for fruit in fruits:
    print(fruit)

# %%
for letter in "Python":
    print(letter)

# %%
for i in range(0, 10, 2):
    print(i)

# %%
for i in range(1, 6):
    print(i)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
